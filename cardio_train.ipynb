# %%
import numpy as np
from scipy.optimize import minimize
import pandas as pd
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
from sklearn.impute import SimpleImputer
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter


from leverage_scores import compute_leverage

from row_sampling import leverage_sampling, l2s_sampling, uniform_sampling

# %% [markdown]
# # **Data cleaning and pre-processing**

# %%
df = pd.read_csv("cardio_train.csv", sep=';')
df.drop(df.columns[0], axis=1, inplace=True)
df.info()
X_raw = df.drop('cardio', axis=1).values
y= df['cardio'].values

scaler = StandardScaler()
X = scaler.fit_transform(X_raw)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          70000 non-null  int64
#  1   gender       70000 non-null  int64
#  2   height       70000 non-null  int64
#  3   weight       70000 non-null  float64
#  4   ap_hi        70000 non-null  int64
#  5   ap_lo        70000 non-null  int64
#  6   cholesterol  70000 non-null  int64
#  7   gluc         70000 non-null  int64
#  8   smoke        70000 non-null  int64
#  9   alco         70000 non-null  int64
#  10  active       70000 non-null  int64
#  11  cardio       70000 non-null  int64
# dtypes: float64(1), int64(11)
# memory usage: 6.4 MB

# %% [markdown]
# # **Define the necessary functions for gradient, NLL etc.**

# %%
# Logistic function (sigmoid)
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# Negative log likelihood
def neg_log_likelihood(theta, X, y):
    z = np.dot(X, theta)
    return -np.sum(y * z - np.logaddexp(0, z))

def lev_neg_log_likelihood(theta, X, y):
    z = np.dot(X, theta)
    log_sum_exp = np.logaddexp(0, z)
    return -np.sum(w*y[ind] * z[ind] - w*log_sum_exp[ind])

def l2s_neg_log_likelihood(theta, X, y):
    z = np.dot(X, theta)
    return -np.sum(w_l2s * y[ind_l2s] * z[ind_l2s] - w_l2s * np.logaddexp(0, z)[ind_l2s])

def unif_neg_log_likelihood(theta, X, y):
    z = np.dot(X, theta)
    log_sum_exp = np.logaddexp(0, z)
    return -np.sum(y[ind_unif] * z[ind_unif] - log_sum_exp[ind_unif])



# Gradient of negative log likelihood
def gradient(theta, X, y):
    z = np.dot(X, theta)
    return np.dot(X.T, sigmoid(z) - y)

def lev_gradient(theta, X, y):
    z = np.dot(X, theta)
    return np.dot(X.T[:,ind], np.dot(np.diag(w),(sigmoid(z) - y)[ind]))

def l2s_gradient(theta, X, y):
    z = np.dot(X, theta)
    return np.dot(X.T[:,ind_l2s], np.dot(np.diag(w_l2s),(sigmoid(z) - y)[ind_l2s]))

def unif_gradient(theta, X, y):
    z = np.dot(X, theta)
    return np.dot(X.T[:,ind_unif], (sigmoid(z) - y)[ind_unif])

# %% [markdown]
# # **Run the full-data model**

# %%
initial_theta = np.zeros(X.shape[1])

result_opt = minimize(neg_log_likelihood, initial_theta, args=(X, y), 
                              method='BFGS', jac=gradient)

est_probs_opt = (sigmoid(np.dot(X, result_opt.x)))
opt_pred_labels = (est_probs_opt > 0.5).astype(int)
opt_misclassification_rate = np.mean(opt_pred_labels != y)
print(f"Full data misclassification rate: {opt_misclassification_rate: .6f}")
# Out:
# Full data misclassification rate:  0.284657

# %% [markdown]
# # **Run the sampling algorithms for varying sample sizes**

# %%
s_values = range(100,20000,500)

# Number of times to run the analysis for each s value
num_runs = 20

# Initialize lists to store mean relative errors
mean_rel_est_probs_lev_list = []
mean_rel_est_probs_l2s_list = []
mean_rel_est_probs_unif_list = []

mean_lev_misclassification_rate_list = []
mean_l2s_misclassification_rate_list = []
mean_unif_misclassification_rate_list = []

mean_rel_lev_neg_log_likelihood_list = []
mean_rel_l2s_neg_log_likelihood_list = []
mean_rel_unif_neg_log_likelihood_list = []

mean_rel_lev_true_neg_log_likelihood_list = []
mean_rel_l2s_true_neg_log_likelihood_list = []
mean_rel_unif_true_neg_log_likelihood_list = []


# Initialize lists for standard deviations

std_rel_est_probs_lev_list = []
std_rel_est_probs_l2s_list = []
std_rel_est_probs_unif_list = []

std_lev_misclassification_rate_list = []
std_l2s_misclassification_rate_list = []
std_unif_misclassification_rate_list = []

std_rel_lev_neg_log_likelihood_list = []
std_rel_l2s_neg_log_likelihood_list = []
std_rel_unif_neg_log_likelihood_list = []

std_rel_lev_true_neg_log_likelihood_list = []
std_rel_l2s_true_neg_log_likelihood_list = []
std_rel_unif_true_neg_log_likelihood_list = []



for s in s_values:
    
    rel_est_probs_lev_list = []
    rel_est_probs_l2s_list = []
    rel_est_probs_unif_list = []
    
    lev_misclassification_rate_list = []
    l2s_misclassification_rate_list = []
    unif_misclassification_rate_list = []
    
    rel_lev_neg_log_likelihood_list = []
    rel_l2s_neg_log_likelihood_list = []
    rel_unif_neg_log_likelihood_list = []
    
    rel_lev_true_neg_log_likelihood_list = []
    rel_l2s_true_neg_log_likelihood_list = []
    rel_unif_true_neg_log_likelihood_list = []

    for run in range(num_runs):
        
        
        # Pick the indices and weights for leverage, l2s, and uniform sampling
        ind, w = leverage_sampling (data=X, size=s)

        ind_l2s, w_l2s = l2s_sampling(data=X, size=s, k=20)

        ind_unif = uniform_sampling(data=X, size=s)
        
        

        # Calculate parameters using leverage, l2s, and uniform methods
        result_lev = minimize(lev_neg_log_likelihood, initial_theta, args=(X, y), 
                              method='BFGS', jac=lev_gradient)
        
        result_l2s = minimize(l2s_neg_log_likelihood, initial_theta, args=(X, y), 
                              method='BFGS', jac=l2s_gradient)

        result_unif = minimize(unif_neg_log_likelihood, initial_theta, args=(X, y), 
                              method='BFGS', jac=unif_gradient)

        
        # Calculate estimated probabilities and predicted labels
        est_probs_lev = (sigmoid(np.dot(X, result_lev.x)))
        est_probs_l2s = (sigmoid(np.dot(X, result_l2s.x)))
        est_probs_unif = (sigmoid(np.dot(X, result_unif.x)))

        lev_pred_labels = (est_probs_lev > 0.5).astype(int)
        l2s_pred_labels = (est_probs_l2s > 0.5).astype(int)
        unif_pred_labels = (est_probs_unif > 0.5).astype(int)

        # Calculate misclassification rates and relative errors
        
        rel_est_probs_lev = np.linalg.norm(est_probs_lev - est_probs_opt) / np.linalg.norm(est_probs_opt)
        rel_est_probs_l2s = np.linalg.norm(est_probs_l2s - est_probs_opt) / np.linalg.norm(est_probs_opt)
        rel_est_probs_unif = np.linalg.norm(est_probs_unif - est_probs_opt) / np.linalg.norm(est_probs_opt)
        
        lev_misclassification_rate = np.mean(lev_pred_labels != y)
        l2s_misclassification_rate = np.mean(l2s_pred_labels != y)
        unif_misclassification_rate = np.mean(unif_pred_labels != y)
        
        rel_lev_neg_log_likelihood= np.abs(neg_log_likelihood(result_opt.x,X,y)-lev_neg_log_likelihood(result_lev.x,X,y))/neg_log_likelihood(result_opt.x,X,y)
        rel_l2s_neg_log_likelihood= np.abs(neg_log_likelihood(result_opt.x,X,y)-l2s_neg_log_likelihood(result_l2s.x,X,y))/neg_log_likelihood(result_opt.x,X,y)                    
        rel_unif_neg_log_likelihood= np.abs(neg_log_likelihood(result_opt.x,X,y)-unif_neg_log_likelihood(result_unif.x,X,y))/neg_log_likelihood(result_opt.x,X,y)

        rel_lev_true_neg_log_likelihood= np.abs(neg_log_likelihood(result_opt.x,X,y)-neg_log_likelihood(result_lev.x,X,y))/neg_log_likelihood(result_opt.x,X,y)
        rel_l2s_true_neg_log_likelihood= np.abs(neg_log_likelihood(result_opt.x,X,y)-neg_log_likelihood(result_l2s.x,X,y))/neg_log_likelihood(result_opt.x,X,y)                    
        rel_unif_true_neg_log_likelihood= np.abs(neg_log_likelihood(result_opt.x,X,y)-neg_log_likelihood(result_unif.x,X,y))/neg_log_likelihood(result_opt.x,X,y)

        
        # Append to lists
        
        rel_est_probs_lev_list.append(rel_est_probs_lev)
        rel_est_probs_l2s_list.append(rel_est_probs_l2s)
        rel_est_probs_unif_list.append(rel_est_probs_unif)
        
        lev_misclassification_rate_list.append(lev_misclassification_rate)
        l2s_misclassification_rate_list.append(l2s_misclassification_rate)
        unif_misclassification_rate_list.append(unif_misclassification_rate)
        
        rel_lev_neg_log_likelihood_list.append(rel_lev_neg_log_likelihood)
        rel_l2s_neg_log_likelihood_list.append(rel_l2s_neg_log_likelihood)
        rel_unif_neg_log_likelihood_list.append(rel_unif_neg_log_likelihood)
        
        rel_lev_true_neg_log_likelihood_list.append(rel_lev_true_neg_log_likelihood)
        rel_l2s_true_neg_log_likelihood_list.append(rel_l2s_true_neg_log_likelihood)
        rel_unif_true_neg_log_likelihood_list.append(rel_unif_true_neg_log_likelihood)      


    # Calculate mean relative errors for each s value
    
    mean_rel_est_probs_lev = np.mean(rel_est_probs_lev_list)
    mean_rel_est_probs_l2s = np.mean(rel_est_probs_l2s_list)
    mean_rel_est_probs_unif = np.mean(rel_est_probs_unif_list)
                              
    mean_lev_misclassification_rate = np.mean(lev_misclassification_rate_list)
    mean_l2s_misclassification_rate = np.mean(l2s_misclassification_rate_list)                          
    mean_unif_misclassification_rate = np.mean(unif_misclassification_rate_list)
    
    mean_rel_lev_neg_log_likelihood = np.mean(rel_lev_neg_log_likelihood_list)
    mean_rel_l2s_neg_log_likelihood = np.mean(rel_l2s_neg_log_likelihood_list)
    mean_rel_unif_neg_log_likelihood = np.mean(rel_unif_neg_log_likelihood_list)
    
    mean_rel_lev_true_neg_log_likelihood = np.mean(rel_lev_true_neg_log_likelihood_list)
    mean_rel_l2s_true_neg_log_likelihood = np.mean(rel_l2s_true_neg_log_likelihood_list)
    mean_rel_unif_true_neg_log_likelihood = np.mean(rel_unif_true_neg_log_likelihood_list)
    
    # Calculate standard deviations of errors for each s value
    
    std_rel_est_probs_lev = np.std(rel_est_probs_lev_list)
    std_rel_est_probs_l2s = np.std(rel_est_probs_l2s_list)
    std_rel_est_probs_unif = np.std(rel_est_probs_unif_list)
                              
    std_lev_misclassification_rate = np.std(lev_misclassification_rate_list)
    std_l2s_misclassification_rate = np.std(l2s_misclassification_rate_list)                          
    std_unif_misclassification_rate = np.std(unif_misclassification_rate_list)
    
    std_rel_lev_neg_log_likelihood = np.std(rel_lev_neg_log_likelihood_list)
    std_rel_l2s_neg_log_likelihood = np.std(rel_l2s_neg_log_likelihood_list)
    std_rel_unif_neg_log_likelihood = np.std(rel_unif_neg_log_likelihood_list)
    
    std_rel_lev_true_neg_log_likelihood = np.std(rel_lev_true_neg_log_likelihood_list)
    std_rel_l2s_true_neg_log_likelihood = np.std(rel_l2s_true_neg_log_likelihood_list)
    std_rel_unif_true_neg_log_likelihood = np.std(rel_unif_true_neg_log_likelihood_list)
    
    
    # Append mean values to the lists
    
    mean_rel_est_probs_lev_list.append(mean_rel_est_probs_lev)
    mean_rel_est_probs_l2s_list.append(mean_rel_est_probs_l2s)
    mean_rel_est_probs_unif_list.append(mean_rel_est_probs_unif)
                              
    mean_lev_misclassification_rate_list.append(mean_lev_misclassification_rate)
    mean_l2s_misclassification_rate_list.append(mean_l2s_misclassification_rate)
    mean_unif_misclassification_rate_list.append(mean_unif_misclassification_rate)
    
    mean_rel_lev_neg_log_likelihood_list.append(mean_rel_lev_neg_log_likelihood)
    mean_rel_l2s_neg_log_likelihood_list.append(mean_rel_l2s_neg_log_likelihood)
    mean_rel_unif_neg_log_likelihood_list.append(mean_rel_unif_neg_log_likelihood)
    
    mean_rel_lev_true_neg_log_likelihood_list.append(mean_rel_lev_true_neg_log_likelihood)
    mean_rel_l2s_true_neg_log_likelihood_list.append(mean_rel_l2s_true_neg_log_likelihood)
    mean_rel_unif_true_neg_log_likelihood_list.append(mean_rel_unif_true_neg_log_likelihood)
    
    # Append standard deviation values to the lists
    
    std_rel_est_probs_lev_list.append(std_rel_est_probs_lev)
    std_rel_est_probs_l2s_list.append(std_rel_est_probs_l2s)
    std_rel_est_probs_unif_list.append(std_rel_est_probs_unif)
                              
    std_lev_misclassification_rate_list.append(std_lev_misclassification_rate)
    std_l2s_misclassification_rate_list.append(std_l2s_misclassification_rate)
    std_unif_misclassification_rate_list.append(std_unif_misclassification_rate)
    
    std_rel_lev_neg_log_likelihood_list.append(std_rel_lev_neg_log_likelihood)
    std_rel_l2s_neg_log_likelihood_list.append(std_rel_l2s_neg_log_likelihood)
    std_rel_unif_neg_log_likelihood_list.append(std_rel_unif_neg_log_likelihood)
    
    std_rel_lev_true_neg_log_likelihood_list.append(std_rel_lev_true_neg_log_likelihood)
    std_rel_l2s_true_neg_log_likelihood_list.append(std_rel_l2s_true_neg_log_likelihood)
    std_rel_unif_true_neg_log_likelihood_list.append(std_rel_unif_true_neg_log_likelihood)
                              

    # Print the mean relative errors for each s
                             
    print(f"Mean Relative Error Estimated Probs Leverage for s = {s}: {mean_rel_est_probs_lev}")
    print(f"Mean Relative Error Estimated Probs L2S for s = {s}: {mean_rel_est_probs_l2s}")
    print(f"Mean Relative Error Estimated Probs Uniform for s = {s}: {mean_rel_est_probs_unif}")
    print("-----------------------------------------------------------------------")                          
    print(f"Mean Leverage Misclassification Rate for s = {s}: {mean_lev_misclassification_rate}")
    print(f"Mean L2S Misclassification Rate for s = {s}: {mean_l2s_misclassification_rate}")
    print(f"Mean Uniform Misclassification Rate for s = {s}: {mean_unif_misclassification_rate}")
    print("-----------------------------------------------------------------------") 
    print(f"Mean Relative Error Leverage Negative Log Likelihood for s = {s}: {mean_rel_lev_neg_log_likelihood}")
    print(f"Mean Relative Error L2S Negative Log Likelihood for s = {s}: {mean_rel_l2s_neg_log_likelihood}")
    print(f"Mean Relative Error Uniform Negative Log Likelihood for s = {s}: {mean_rel_unif_neg_log_likelihood}")
    print("-----------------------------------------------------------------------") 
    print(f"Mean Relative Error Leverage True Negative Log Likelihood for s = {s}: {mean_rel_lev_true_neg_log_likelihood}")
    print(f"Mean Relative Error L2S Negative True Log Likelihood for s = {s}: {mean_rel_l2s_true_neg_log_likelihood}")
    print(f"Mean Relative Error Uniform True Negative Log Likelihood for s = {s}: {mean_rel_unif_true_neg_log_likelihood}")
    print("=" * 60)
    


# Convert lists to arrays    

# mean
mean_rel_est_probs_lev_array = np.array(mean_rel_est_probs_lev_list)
mean_rel_est_probs_l2s_array = np.array(mean_rel_est_probs_l2s_list)
mean_rel_est_probs_unif_array = np.array(mean_rel_est_probs_unif_list)
                              
mean_lev_misclassification_rate_array = np.array(mean_lev_misclassification_rate_list)
mean_l2s_misclassification_rate_array = np.array(mean_l2s_misclassification_rate_list)
mean_unif_misclassification_rate_array = np.array(mean_unif_misclassification_rate_list)

mean_rel_lev_neg_log_likelihood_array = np.array(mean_rel_lev_neg_log_likelihood_list)
mean_rel_l2s_neg_log_likelihood_array = np.array(mean_rel_l2s_neg_log_likelihood_list)
mean_rel_unif_neg_log_likelihood_array = np.array(mean_rel_unif_neg_log_likelihood_list)

mean_rel_lev_true_neg_log_likelihood_array = np.array(mean_rel_lev_true_neg_log_likelihood_list)
mean_rel_l2s_true_neg_log_likelihood_array = np.array(mean_rel_l2s_true_neg_log_likelihood_list)
mean_rel_unif_true_neg_log_likelihood_array = np.array(mean_rel_unif_true_neg_log_likelihood_list)

# stdev
std_rel_est_probs_lev_array = np.array(std_rel_est_probs_lev_list)
std_rel_est_probs_l2s_array = np.array(std_rel_est_probs_l2s_list)
std_rel_est_probs_unif_array = np.array(std_rel_est_probs_unif_list)
                              
std_lev_misclassification_rate_array = np.array(std_lev_misclassification_rate_list)
std_l2s_misclassification_rate_array = np.array(std_l2s_misclassification_rate_list)
std_unif_misclassification_rate_array = np.array(std_unif_misclassification_rate_list)

std_rel_lev_neg_log_likelihood_array = np.array(std_rel_lev_neg_log_likelihood_list)
std_rel_l2s_neg_log_likelihood_array = np.array(std_rel_l2s_neg_log_likelihood_list)
std_rel_unif_neg_log_likelihood_array = np.array(std_rel_unif_neg_log_likelihood_list)

std_rel_lev_true_neg_log_likelihood_array = np.array(std_rel_lev_true_neg_log_likelihood_list)
std_rel_l2s_true_neg_log_likelihood_array = np.array(std_rel_l2s_true_neg_log_likelihood_list)
std_rel_unif_true_neg_log_likelihood_array = np.array(std_rel_unif_true_neg_log_likelihood_list)
# Out:
# Mean Relative Error Estimated Probs Leverage for s = 100: 0.3571580785788972
# Mean Relative Error Estimated Probs L2S for s = 100: 0.29521197161814927
# Mean Relative Error Estimated Probs Uniform for s = 100: 0.3029527965401547
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 100: 0.33744285714285716
# Mean L2S Misclassification Rate for s = 100: 0.3325985714285714
# Mean Uniform Misclassification Rate for s = 100: 0.31671571428571427
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 100: 0.18196476365719239
# Mean Relative Error L2S Negative Log Likelihood for s = 100: 0.11086449563170213
# Mean Relative Error Uniform Negative Log Likelihood for s = 100: 0.9987811278783647
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 100: 0.22842228611608056
# Mean Relative Error L2S Negative True Log Likelihood for s = 100: 0.12809862390444782
# Mean Relative Error Uniform True Negative Log Likelihood for s = 100: 0.29898857502729276
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 600: 0.13610679981709442
# Mean Relative Error Estimated Probs L2S for s = 600: 0.12925364674615197
# Mean Relative Error Estimated Probs Uniform for s = 600: 0.13731354017952463
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 600: 0.29141571428571433
# Mean L2S Misclassification Rate for s = 600: 0.30092928571428573
# Mean Uniform Misclassification Rate for s = 600: 0.2841407142857143
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 600: 0.03307096561127041
# Mean Relative Error L2S Negative Log Likelihood for s = 600: 0.03298285011608375
# Mean Relative Error Uniform Negative Log Likelihood for s = 600: 0.9919731204876323
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 600: 0.023266247497468088
# Mean Relative Error L2S Negative True Log Likelihood for s = 600: 0.024707972855559236
# Mean Relative Error Uniform True Negative Log Likelihood for s = 600: 0.026555500900279454
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 1100: 0.10300508009756941
# Mean Relative Error Estimated Probs L2S for s = 1100: 0.08761294120723151
# Mean Relative Error Estimated Probs Uniform for s = 1100: 0.1023895074687837
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 1100: 0.2922757142857143
# Mean L2S Misclassification Rate for s = 1100: 0.2846914285714285
# Mean Uniform Misclassification Rate for s = 1100: 0.28529499999999997
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 1100: 0.04092256895679025
# Mean Relative Error L2S Negative Log Likelihood for s = 1100: 0.028584964087954818
# Mean Relative Error Uniform Negative Log Likelihood for s = 1100: 0.9848912342003293
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 1100: 0.012956033895744323
# Mean Relative Error L2S Negative True Log Likelihood for s = 1100: 0.009961953157481152
# Mean Relative Error Uniform True Negative Log Likelihood for s = 1100: 0.014905538409066475
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 1600: 0.08061726748841297
# Mean Relative Error Estimated Probs L2S for s = 1600: 0.0799664505899125
# Mean Relative Error Estimated Probs Uniform for s = 1600: 0.11103797466064884
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 1600: 0.2880878571428571
# Mean L2S Misclassification Rate for s = 1600: 0.28606499999999996
# Mean Uniform Misclassification Rate for s = 1600: 0.2897907142857143
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 1600: 0.02646193425029878
# Mean Relative Error L2S Negative Log Likelihood for s = 1600: 0.02225935935556802
# Mean Relative Error Uniform Negative Log Likelihood for s = 1600: 0.9780588458490012
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 1600: 0.007974191869977375
# Mean Relative Error L2S Negative True Log Likelihood for s = 1600: 0.008109193191640957
# Mean Relative Error Uniform True Negative Log Likelihood for s = 1600: 0.018340812998640564
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 2100: 0.06703859953308929
# Mean Relative Error Estimated Probs L2S for s = 2100: 0.0587082855377158
# Mean Relative Error Estimated Probs Uniform for s = 2100: 0.09155406182292691
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 2100: 0.2867464285714285
# Mean L2S Misclassification Rate for s = 2100: 0.28432785714285724
# Mean Uniform Misclassification Rate for s = 2100: 0.2857871428571429
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 2100: 0.026739856411045693
# Mean Relative Error L2S Negative Log Likelihood for s = 2100: 0.01995742514948579
# Mean Relative Error Uniform Negative Log Likelihood for s = 2100: 0.9713523170746333
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 2100: 0.0056767285107571985
# Mean Relative Error L2S Negative True Log Likelihood for s = 2100: 0.004680915138095761
# Mean Relative Error Uniform True Negative Log Likelihood for s = 2100: 0.012347503501455987
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 2600: 0.06396660350339638
# Mean Relative Error Estimated Probs L2S for s = 2600: 0.05784429154109243
# Mean Relative Error Estimated Probs Uniform for s = 2600: 0.08468358930603245
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 2600: 0.28656928571428575
# Mean L2S Misclassification Rate for s = 2600: 0.2844457142857143
# Mean Uniform Misclassification Rate for s = 2600: 0.28602571428571427
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 2600: 0.030709019500574152
# Mean Relative Error L2S Negative Log Likelihood for s = 2600: 0.018857637762861916
# Mean Relative Error Uniform Negative Log Likelihood for s = 2600: 0.9644948956417702
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 2600: 0.0049896921252015735
# Mean Relative Error L2S Negative True Log Likelihood for s = 2600: 0.004122982398051341
# Mean Relative Error Uniform True Negative Log Likelihood for s = 2600: 0.01087988340012836
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 3100: 0.06057392151034193
# Mean Relative Error Estimated Probs L2S for s = 3100: 0.055581923327899255
# Mean Relative Error Estimated Probs Uniform for s = 3100: 0.09839000193426076
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 3100: 0.28630071428571424
# Mean L2S Misclassification Rate for s = 3100: 0.28381642857142864
# Mean Uniform Misclassification Rate for s = 3100: 0.2884671428571429
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 3100: 0.024917736823472907
# Mean Relative Error L2S Negative Log Likelihood for s = 3100: 0.012394155229173663
# Mean Relative Error Uniform Negative Log Likelihood for s = 3100: 0.9577455589137879
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 3100: 0.004434815516390038
# Mean Relative Error L2S Negative True Log Likelihood for s = 3100: 0.003910837425213951
# Mean Relative Error Uniform True Negative Log Likelihood for s = 3100: 0.014805231038528557
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 3600: 0.05182452612237026
# Mean Relative Error Estimated Probs L2S for s = 3600: 0.05327125088872529
# Mean Relative Error Estimated Probs Uniform for s = 3600: 0.0994646061371191
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 3600: 0.2866842857142857
# Mean L2S Misclassification Rate for s = 3600: 0.2826542857142857
# Mean Uniform Misclassification Rate for s = 3600: 0.2880178571428572
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 3600: 0.0209943446295203
# Mean Relative Error L2S Negative Log Likelihood for s = 3600: 0.015666532295686732
# Mean Relative Error Uniform Negative Log Likelihood for s = 3600: 0.9513983723646634
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 3600: 0.0033764103527934757
# Mean Relative Error L2S Negative True Log Likelihood for s = 3600: 0.0038276662495532964
# Mean Relative Error Uniform True Negative Log Likelihood for s = 3600: 0.014996934560841257
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 4100: 0.05160686624447954
# Mean Relative Error Estimated Probs L2S for s = 4100: 0.056292235144504564
# Mean Relative Error Estimated Probs Uniform for s = 4100: 0.07592033173172832
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 4100: 0.28607214285714283
# Mean L2S Misclassification Rate for s = 4100: 0.28183499999999995
# Mean Uniform Misclassification Rate for s = 4100: 0.28505357142857146
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 4100: 0.016695054731776023
# Mean Relative Error L2S Negative Log Likelihood for s = 4100: 0.014465334222938397
# Mean Relative Error Uniform Negative Log Likelihood for s = 4100: 0.9447061071731314
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 4100: 0.00322334763636375
# Mean Relative Error L2S Negative True Log Likelihood for s = 4100: 0.00413788925435306
# Mean Relative Error Uniform True Negative Log Likelihood for s = 4100: 0.009367872980574028
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 4600: 0.048748641758048064
# Mean Relative Error Estimated Probs L2S for s = 4600: 0.049992645135973554
# Mean Relative Error Estimated Probs Uniform for s = 4600: 0.06668643333157544
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 4600: 0.2844035714285714
# Mean L2S Misclassification Rate for s = 4600: 0.282625
# Mean Uniform Misclassification Rate for s = 4600: 0.2809771428571429
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 4600: 0.015884275633724482
# Mean Relative Error L2S Negative Log Likelihood for s = 4600: 0.013606558317588313
# Mean Relative Error Uniform Negative Log Likelihood for s = 4600: 0.9383668049743477
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 4600: 0.0027735039539120597
# Mean Relative Error L2S Negative True Log Likelihood for s = 4600: 0.00343019474004718
# Mean Relative Error Uniform True Negative Log Likelihood for s = 4600: 0.0061506666845309544
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 5100: 0.04065930419686172
# Mean Relative Error Estimated Probs L2S for s = 5100: 0.04704539697216914
# Mean Relative Error Estimated Probs Uniform for s = 5100: 0.09661831856479891
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 5100: 0.2848921428571429
# Mean L2S Misclassification Rate for s = 5100: 0.28228571428571425
# Mean Uniform Misclassification Rate for s = 5100: 0.29537
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 5100: 0.014515081580753925
# Mean Relative Error L2S Negative Log Likelihood for s = 5100: 0.01590238875643208
# Mean Relative Error Uniform Negative Log Likelihood for s = 5100: 0.9302504535433231
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 5100: 0.002030828581982359
# Mean Relative Error L2S Negative True Log Likelihood for s = 5100: 0.003175946903862798
# Mean Relative Error Uniform True Negative Log Likelihood for s = 5100: 0.016282826429798027
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 5600: 0.0407409837694946
# Mean Relative Error Estimated Probs L2S for s = 5600: 0.04277865355186321
# Mean Relative Error Estimated Probs Uniform for s = 5600: 0.08233883048883268
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 5600: 0.2841857142857143
# Mean L2S Misclassification Rate for s = 5600: 0.28248928571428567
# Mean Uniform Misclassification Rate for s = 5600: 0.2875842857142857
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 5600: 0.01786842636943468
# Mean Relative Error L2S Negative Log Likelihood for s = 5600: 0.00861899159969971
# Mean Relative Error Uniform Negative Log Likelihood for s = 5600: 0.9251958189847672
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 5600: 0.0019563888630558255
# Mean Relative Error L2S Negative True Log Likelihood for s = 5600: 0.0022934099311120136
# Mean Relative Error Uniform True Negative Log Likelihood for s = 5600: 0.011493961012816249
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 6100: 0.03927885665400073
# Mean Relative Error Estimated Probs L2S for s = 6100: 0.04928699582719444
# Mean Relative Error Estimated Probs Uniform for s = 6100: 0.060169521136826054
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 6100: 0.2842635714285714
# Mean L2S Misclassification Rate for s = 6100: 0.2814292857142857
# Mean Uniform Misclassification Rate for s = 6100: 0.28068714285714286
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 6100: 0.016483293234725936
# Mean Relative Error L2S Negative Log Likelihood for s = 6100: 0.012495193700752015
# Mean Relative Error Uniform Negative Log Likelihood for s = 6100: 0.9189101281966598
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 6100: 0.0018115490538713253
# Mean Relative Error L2S Negative True Log Likelihood for s = 6100: 0.003192303806626909
# Mean Relative Error Uniform True Negative Log Likelihood for s = 6100: 0.005122876074576231
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 6600: 0.043984831234303606
# Mean Relative Error Estimated Probs L2S for s = 6600: 0.048708690085033354
# Mean Relative Error Estimated Probs Uniform for s = 6600: 0.09307338058772491
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 6600: 0.2844364285714286
# Mean L2S Misclassification Rate for s = 6600: 0.28109500000000004
# Mean Uniform Misclassification Rate for s = 6600: 0.2949364285714286
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 6600: 0.015037073113625723
# Mean Relative Error L2S Negative Log Likelihood for s = 6600: 0.008120672296665058
# Mean Relative Error Uniform Negative Log Likelihood for s = 6600: 0.9105074419563224
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 6600: 0.002310436367171982
# Mean Relative Error L2S Negative True Log Likelihood for s = 6600: 0.0030444324571907606
# Mean Relative Error Uniform True Negative Log Likelihood for s = 6600: 0.014568618566366525
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 7100: 0.03857104820209929
# Mean Relative Error Estimated Probs L2S for s = 7100: 0.04158781732363033
# Mean Relative Error Estimated Probs Uniform for s = 7100: 0.06741455901360192
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 7100: 0.2840957142857143
# Mean L2S Misclassification Rate for s = 7100: 0.28190142857142864
# Mean Uniform Misclassification Rate for s = 7100: 0.28258285714285714
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 7100: 0.016235476755195086
# Mean Relative Error L2S Negative Log Likelihood for s = 7100: 0.009425699694537465
# Mean Relative Error Uniform Negative Log Likelihood for s = 7100: 0.9060793399104977
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 7100: 0.0017526736888010164
# Mean Relative Error L2S Negative True Log Likelihood for s = 7100: 0.0023122549054654627
# Mean Relative Error Uniform True Negative Log Likelihood for s = 7100: 0.006697388076004261
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 7600: 0.03913787410317654
# Mean Relative Error Estimated Probs L2S for s = 7600: 0.04275032992072163
# Mean Relative Error Estimated Probs Uniform for s = 7600: 0.07448615572759991
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 7600: 0.28507571428571427
# Mean L2S Misclassification Rate for s = 7600: 0.281255
# Mean Uniform Misclassification Rate for s = 7600: 0.28923428571428567
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 7600: 0.018397773332796147
# Mean Relative Error L2S Negative Log Likelihood for s = 7600: 0.00940519981049224
# Mean Relative Error Uniform Negative Log Likelihood for s = 7600: 0.8986492855895436
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 7600: 0.0019518544440856388
# Mean Relative Error L2S Negative True Log Likelihood for s = 7600: 0.002403355286515833
# Mean Relative Error Uniform True Negative Log Likelihood for s = 7600: 0.009690515011505163
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 8100: 0.037744201446636115
# Mean Relative Error Estimated Probs L2S for s = 8100: 0.04717762448707287
# Mean Relative Error Estimated Probs Uniform for s = 8100: 0.08486527391564375
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 8100: 0.28439285714285717
# Mean L2S Misclassification Rate for s = 8100: 0.281165
# Mean Uniform Misclassification Rate for s = 8100: 0.2910335714285714
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 8100: 0.011571411914362388
# Mean Relative Error L2S Negative Log Likelihood for s = 8100: 0.010658840578609228
# Mean Relative Error Uniform Negative Log Likelihood for s = 8100: 0.8919937814336814
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 8100: 0.0017299683131304978
# Mean Relative Error L2S Negative True Log Likelihood for s = 8100: 0.002973015742448458
# Mean Relative Error Uniform True Negative Log Likelihood for s = 8100: 0.010966904561163587
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 8600: 0.03829233704739565
# Mean Relative Error Estimated Probs L2S for s = 8600: 0.04904799042818553
# Mean Relative Error Estimated Probs Uniform for s = 8600: 0.07075592574592646
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 8600: 0.28479571428571426
# Mean L2S Misclassification Rate for s = 8600: 0.2812928571428572
# Mean Uniform Misclassification Rate for s = 8600: 0.2854385714285714
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 8600: 0.013360558114935153
# Mean Relative Error L2S Negative Log Likelihood for s = 8600: 0.010611090511814853
# Mean Relative Error Uniform Negative Log Likelihood for s = 8600: 0.8863209716837813
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 8600: 0.0017197614785959866
# Mean Relative Error L2S Negative True Log Likelihood for s = 8600: 0.0032966060002951126
# Mean Relative Error Uniform True Negative Log Likelihood for s = 8600: 0.007651315444502078
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 9100: 0.03402341121836312
# Mean Relative Error Estimated Probs L2S for s = 9100: 0.04814610084405885
# Mean Relative Error Estimated Probs Uniform for s = 9100: 0.08430472267318498
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 9100: 0.28382142857142856
# Mean L2S Misclassification Rate for s = 9100: 0.2810171428571429
# Mean Uniform Misclassification Rate for s = 9100: 0.2892935714285715
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 9100: 0.013221684757397495
# Mean Relative Error L2S Negative Log Likelihood for s = 9100: 0.0083450894484947
# Mean Relative Error Uniform Negative Log Likelihood for s = 9100: 0.8798504315586992
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 9100: 0.001445983949003989
# Mean Relative Error L2S Negative True Log Likelihood for s = 9100: 0.0030838457527879886
# Mean Relative Error Uniform True Negative Log Likelihood for s = 9100: 0.010155640573921917
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 9600: 0.033969669774034775
# Mean Relative Error Estimated Probs L2S for s = 9600: 0.046077875544599654
# Mean Relative Error Estimated Probs Uniform for s = 9600: 0.06860985315557472
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 9600: 0.2847835714285714
# Mean L2S Misclassification Rate for s = 9600: 0.2810557142857143
# Mean Uniform Misclassification Rate for s = 9600: 0.28558928571428566
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 9600: 0.013283831021778362
# Mean Relative Error L2S Negative Log Likelihood for s = 9600: 0.01037049609517825
# Mean Relative Error Uniform Negative Log Likelihood for s = 9600: 0.8743033296220227
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 9600: 0.0014784213874189705
# Mean Relative Error L2S Negative True Log Likelihood for s = 9600: 0.00282753925523733
# Mean Relative Error Uniform True Negative Log Likelihood for s = 9600: 0.00704567469520032
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 10100: 0.03206633310627447
# Mean Relative Error Estimated Probs L2S for s = 10100: 0.049429888822126684
# Mean Relative Error Estimated Probs Uniform for s = 10100: 0.09936417503625972
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 10100: 0.2846235714285714
# Mean L2S Misclassification Rate for s = 10100: 0.28069571428571427
# Mean Uniform Misclassification Rate for s = 10100: 0.296705
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 10100: 0.011571398314457535
# Mean Relative Error L2S Negative Log Likelihood for s = 10100: 0.00777392981073131
# Mean Relative Error Uniform Negative Log Likelihood for s = 10100: 0.8645724293779711
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 10100: 0.0012303811511848973
# Mean Relative Error L2S Negative True Log Likelihood for s = 10100: 0.0033041778021310037
# Mean Relative Error Uniform True Negative Log Likelihood for s = 10100: 0.013751181717020469
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 10600: 0.031551786472678006
# Mean Relative Error Estimated Probs L2S for s = 10600: 0.04987406871654408
# Mean Relative Error Estimated Probs Uniform for s = 10600: 0.06683194695491294
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 10600: 0.28426142857142855
# Mean L2S Misclassification Rate for s = 10600: 0.28074499999999997
# Mean Uniform Misclassification Rate for s = 10600: 0.2865314285714286
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 10600: 0.011985238162636126
# Mean Relative Error L2S Negative Log Likelihood for s = 10600: 0.011260717046742957
# Mean Relative Error Uniform Negative Log Likelihood for s = 10600: 0.8610809009702329
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 10600: 0.0011565821130677474
# Mean Relative Error L2S Negative True Log Likelihood for s = 10600: 0.003391502529966335
# Mean Relative Error Uniform True Negative Log Likelihood for s = 10600: 0.006726420429459944
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 11100: 0.030020207447576597
# Mean Relative Error Estimated Probs L2S for s = 11100: 0.04746804376604909
# Mean Relative Error Estimated Probs Uniform for s = 11100: 0.072202742189877
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 11100: 0.2846785714285714
# Mean L2S Misclassification Rate for s = 11100: 0.2806707142857144
# Mean Uniform Misclassification Rate for s = 11100: 0.2884085714285714
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 11100: 0.01095071016090583
# Mean Relative Error L2S Negative Log Likelihood for s = 11100: 0.006069072458712514
# Mean Relative Error Uniform Negative Log Likelihood for s = 11100: 0.8551009004260542
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 11100: 0.001096620370320244
# Mean Relative Error L2S Negative True Log Likelihood for s = 11100: 0.0029489018458839535
# Mean Relative Error Uniform True Negative Log Likelihood for s = 11100: 0.008671963783775206
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 11600: 0.030132937615134255
# Mean Relative Error Estimated Probs L2S for s = 11600: 0.05346994016337164
# Mean Relative Error Estimated Probs Uniform for s = 11600: 0.07311853378309957
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 11600: 0.2843507142857143
# Mean L2S Misclassification Rate for s = 11600: 0.2802471428571429
# Mean Uniform Misclassification Rate for s = 11600: 0.2878021428571429
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 11600: 0.013819082240097697
# Mean Relative Error L2S Negative Log Likelihood for s = 11600: 0.005789655404085281
# Mean Relative Error Uniform Negative Log Likelihood for s = 11600: 0.8484198666556926
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 11600: 0.0011411866453957752
# Mean Relative Error L2S Negative True Log Likelihood for s = 11600: 0.0037857626308536118
# Mean Relative Error Uniform True Negative Log Likelihood for s = 11600: 0.008708545889450471
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 12100: 0.029580945594249515
# Mean Relative Error Estimated Probs L2S for s = 12100: 0.04889209653011348
# Mean Relative Error Estimated Probs Uniform for s = 12100: 0.07479539864286197
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 12100: 0.2845978571428572
# Mean L2S Misclassification Rate for s = 12100: 0.280395
# Mean Uniform Misclassification Rate for s = 12100: 0.28739500000000007
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 12100: 0.01360389969367895
# Mean Relative Error L2S Negative Log Likelihood for s = 12100: 0.00836909959494188
# Mean Relative Error Uniform Negative Log Likelihood for s = 12100: 0.8431737594747988
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 12100: 0.001077078173451825
# Mean Relative Error L2S Negative True Log Likelihood for s = 12100: 0.003235882172743175
# Mean Relative Error Uniform True Negative Log Likelihood for s = 12100: 0.008477161147867177
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 12600: 0.026230832814355308
# Mean Relative Error Estimated Probs L2S for s = 12600: 0.04581891389179878
# Mean Relative Error Estimated Probs Uniform for s = 12600: 0.0781531759287181
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 12600: 0.2844535714285715
# Mean L2S Misclassification Rate for s = 12600: 0.28083214285714286
# Mean Uniform Misclassification Rate for s = 12600: 0.2916628571428571
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 12600: 0.009347496549802646
# Mean Relative Error L2S Negative Log Likelihood for s = 12600: 0.008416889260787026
# Mean Relative Error Uniform Negative Log Likelihood for s = 12600: 0.8352401961703245
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 12600: 0.0008184305080494905
# Mean Relative Error L2S Negative True Log Likelihood for s = 12600: 0.0028552409128972706
# Mean Relative Error Uniform True Negative Log Likelihood for s = 12600: 0.009315593743423892
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 13100: 0.025019091307646624
# Mean Relative Error Estimated Probs L2S for s = 13100: 0.04952966981690587
# Mean Relative Error Estimated Probs Uniform for s = 13100: 0.07354276322847983
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 13100: 0.2840542857142857
# Mean L2S Misclassification Rate for s = 13100: 0.2803357142857143
# Mean Uniform Misclassification Rate for s = 13100: 0.28981571428571423
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 13100: 0.007999806045614026
# Mean Relative Error L2S Negative Log Likelihood for s = 13100: 0.005947101585689425
# Mean Relative Error Uniform Negative Log Likelihood for s = 13100: 0.8297012631859833
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 13100: 0.000772924833186794
# Mean Relative Error L2S Negative True Log Likelihood for s = 13100: 0.0032421361230748403
# Mean Relative Error Uniform True Negative Log Likelihood for s = 13100: 0.008290961708750906
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 13600: 0.02705410307121032
# Mean Relative Error Estimated Probs L2S for s = 13600: 0.05253042522183933
# Mean Relative Error Estimated Probs Uniform for s = 13600: 0.07363990287995756
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 13600: 0.2843228571428571
# Mean L2S Misclassification Rate for s = 13600: 0.2802464285714285
# Mean Uniform Misclassification Rate for s = 13600: 0.2897142857142857
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 13600: 0.009210438071052564
# Mean Relative Error L2S Negative Log Likelihood for s = 13600: 0.0062806382362774905
# Mean Relative Error Uniform Negative Log Likelihood for s = 13600: 0.8235072779047412
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 13600: 0.0009191692760178647
# Mean Relative Error L2S Negative True Log Likelihood for s = 13600: 0.0036668772255662786
# Mean Relative Error Uniform True Negative Log Likelihood for s = 13600: 0.008046072534936896
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 14100: 0.02672671954396666
# Mean Relative Error Estimated Probs L2S for s = 14100: 0.04711688397688898
# Mean Relative Error Estimated Probs Uniform for s = 14100: 0.060397185421474
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 14100: 0.2841757142857143
# Mean L2S Misclassification Rate for s = 14100: 0.2806121428571429
# Mean Uniform Misclassification Rate for s = 14100: 0.28583285714285717
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 14100: 0.008006486876953071
# Mean Relative Error L2S Negative Log Likelihood for s = 14100: 0.0075696987296714315
# Mean Relative Error Uniform Negative Log Likelihood for s = 14100: 0.8196111215091753
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 14100: 0.0008380866415537575
# Mean Relative Error L2S Negative True Log Likelihood for s = 14100: 0.002959176137991905
# Mean Relative Error Uniform True Negative Log Likelihood for s = 14100: 0.005182325518020154
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 14600: 0.029670581454994405
# Mean Relative Error Estimated Probs L2S for s = 14600: 0.044685813848630074
# Mean Relative Error Estimated Probs Uniform for s = 14600: 0.06068349224664963
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 14600: 0.2852221428571428
# Mean L2S Misclassification Rate for s = 14600: 0.2808178571428571
# Mean Uniform Misclassification Rate for s = 14600: 0.28201071428571434
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 14600: 0.011472047490965975
# Mean Relative Error L2S Negative Log Likelihood for s = 14600: 0.009728307922639123
# Mean Relative Error Uniform Negative Log Likelihood for s = 14600: 0.8157597444974268
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 14600: 0.0010888738103424773
# Mean Relative Error L2S Negative True Log Likelihood for s = 14600: 0.0027617761767959564
# Mean Relative Error Uniform True Negative Log Likelihood for s = 14600: 0.0049694978514474705
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 15100: 0.026488610366194782
# Mean Relative Error Estimated Probs L2S for s = 15100: 0.04696243741490502
# Mean Relative Error Estimated Probs Uniform for s = 15100: 0.0648322405298775
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 15100: 0.28427428571428576
# Mean L2S Misclassification Rate for s = 15100: 0.28059357142857144
# Mean Uniform Misclassification Rate for s = 15100: 0.2852228571428571
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 15100: 0.008793862295088582
# Mean Relative Error L2S Negative Log Likelihood for s = 15100: 0.007991088530932342
# Mean Relative Error Uniform Negative Log Likelihood for s = 15100: 0.8083861652928082
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 15100: 0.0008538164522146893
# Mean Relative Error L2S Negative True Log Likelihood for s = 15100: 0.0028913753686407436
# Mean Relative Error Uniform True Negative Log Likelihood for s = 15100: 0.0054769569639698595
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 15600: 0.02575276719155618
# Mean Relative Error Estimated Probs L2S for s = 15600: 0.05069274539305799
# Mean Relative Error Estimated Probs Uniform for s = 15600: 0.0630970052971376
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 15600: 0.2837921428571428
# Mean L2S Misclassification Rate for s = 15600: 0.280055
# Mean Uniform Misclassification Rate for s = 15600: 0.287065
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 15600: 0.008046124330415471
# Mean Relative Error L2S Negative Log Likelihood for s = 15600: 0.00834814329760996
# Mean Relative Error Uniform Negative Log Likelihood for s = 15600: 0.8005065444934785
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 15600: 0.0007995558859754893
# Mean Relative Error L2S Negative True Log Likelihood for s = 15600: 0.0033426161626704796
# Mean Relative Error Uniform True Negative Log Likelihood for s = 15600: 0.005130348374710084
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 16100: 0.02427913772913977
# Mean Relative Error Estimated Probs L2S for s = 16100: 0.05108552830134774
# Mean Relative Error Estimated Probs Uniform for s = 16100: 0.06193429104929301
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 16100: 0.28473714285714286
# Mean L2S Misclassification Rate for s = 16100: 0.28019928571428565
# Mean Uniform Misclassification Rate for s = 16100: 0.2857085714285715
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 16100: 0.007480946249022595
# Mean Relative Error L2S Negative Log Likelihood for s = 16100: 0.00833498019414328
# Mean Relative Error Uniform Negative Log Likelihood for s = 16100: 0.7969667834557502
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 16100: 0.0006969253877770836
# Mean Relative Error L2S Negative True Log Likelihood for s = 16100: 0.0034552560799795524
# Mean Relative Error Uniform True Negative Log Likelihood for s = 16100: 0.005394343795151848
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 16600: 0.02545894958521643
# Mean Relative Error Estimated Probs L2S for s = 16600: 0.05242124585098651
# Mean Relative Error Estimated Probs Uniform for s = 16600: 0.06008522515762258
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 16600: 0.28471785714285713
# Mean L2S Misclassification Rate for s = 16600: 0.2802107142857143
# Mean Uniform Misclassification Rate for s = 16600: 0.28463428571428573
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 16600: 0.009778208820242478
# Mean Relative Error L2S Negative Log Likelihood for s = 16600: 0.007972012477095291
# Mean Relative Error Uniform Negative Log Likelihood for s = 16600: 0.7917213233462859
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 16600: 0.0007677773784094853
# Mean Relative Error L2S Negative True Log Likelihood for s = 16600: 0.003625942657939645
# Mean Relative Error Uniform True Negative Log Likelihood for s = 16600: 0.004800132729464844
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 17100: 0.0224832765979062
# Mean Relative Error Estimated Probs L2S for s = 17100: 0.051430444028591225
# Mean Relative Error Estimated Probs Uniform for s = 17100: 0.0690008773388089
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 17100: 0.28447642857142863
# Mean L2S Misclassification Rate for s = 17100: 0.28014285714285714
# Mean Uniform Misclassification Rate for s = 17100: 0.28935
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 17100: 0.006870026151167889
# Mean Relative Error L2S Negative Log Likelihood for s = 17100: 0.009511425120863264
# Mean Relative Error Uniform Negative Log Likelihood for s = 17100: 0.7832013136703141
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 17100: 0.0005980135684016236
# Mean Relative Error L2S Negative True Log Likelihood for s = 17100: 0.003454494493216055
# Mean Relative Error Uniform True Negative Log Likelihood for s = 17100: 0.0070820339020190096
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 17600: 0.021778749007819877
# Mean Relative Error Estimated Probs L2S for s = 17600: 0.04987068853461417
# Mean Relative Error Estimated Probs Uniform for s = 17600: 0.055403091341480346
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 17600: 0.2841314285714286
# Mean L2S Misclassification Rate for s = 17600: 0.2803814285714286
# Mean Uniform Misclassification Rate for s = 17600: 0.2855421428571428
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 17600: 0.0107935143150521
# Mean Relative Error L2S Negative Log Likelihood for s = 17600: 0.01131250792832711
# Mean Relative Error Uniform Negative Log Likelihood for s = 17600: 0.7783734081449168
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 17600: 0.0005960107116153655
# Mean Relative Error L2S Negative True Log Likelihood for s = 17600: 0.0033429022044523153
# Mean Relative Error Uniform True Negative Log Likelihood for s = 17600: 0.003946825399318255
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 18100: 0.02241407297034407
# Mean Relative Error Estimated Probs L2S for s = 18100: 0.049330428501412185
# Mean Relative Error Estimated Probs Uniform for s = 18100: 0.05717561581773112
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 18100: 0.28484857142857145
# Mean L2S Misclassification Rate for s = 18100: 0.28028071428571427
# Mean Uniform Misclassification Rate for s = 18100: 0.2839707142857143
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 18100: 0.008529994769447432
# Mean Relative Error L2S Negative Log Likelihood for s = 18100: 0.009827443341123062
# Mean Relative Error Uniform Negative Log Likelihood for s = 18100: 0.7749184056521308
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 18100: 0.0006145102967500634
# Mean Relative Error L2S Negative True Log Likelihood for s = 18100: 0.003231261896595667
# Mean Relative Error Uniform True Negative Log Likelihood for s = 18100: 0.004298912601314451
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 18600: 0.021017856938381273
# Mean Relative Error Estimated Probs L2S for s = 18600: 0.049175930338022825
# Mean Relative Error Estimated Probs Uniform for s = 18600: 0.05689994637783989
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 18600: 0.28420928571428566
# Mean L2S Misclassification Rate for s = 18600: 0.2803628571428571
# Mean Uniform Misclassification Rate for s = 18600: 0.28660571428571424
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 18600: 0.008655674412883747
# Mean Relative Error L2S Negative Log Likelihood for s = 18600: 0.01331460852044065
# Mean Relative Error Uniform Negative Log Likelihood for s = 18600: 0.7664555359902211
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 18600: 0.0005228188490891733
# Mean Relative Error L2S Negative True Log Likelihood for s = 18600: 0.003261629244706099
# Mean Relative Error Uniform True Negative Log Likelihood for s = 18600: 0.004128502920927385
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 19100: 0.02366092115799376
# Mean Relative Error Estimated Probs L2S for s = 19100: 0.05013000215369273
# Mean Relative Error Estimated Probs Uniform for s = 19100: 0.05749804971923354
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 19100: 0.284425
# Mean L2S Misclassification Rate for s = 19100: 0.28023642857142855
# Mean Uniform Misclassification Rate for s = 19100: 0.2843835714285714
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 19100: 0.004393637158243173
# Mean Relative Error L2S Negative Log Likelihood for s = 19100: 0.010146075221285479
# Mean Relative Error Uniform Negative Log Likelihood for s = 19100: 0.7634233496260927
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 19100: 0.0006775757418506261
# Mean Relative Error L2S Negative True Log Likelihood for s = 19100: 0.003348976718908751
# Mean Relative Error Uniform True Negative Log Likelihood for s = 19100: 0.004242699360120704
# ============================================================
# Mean Relative Error Estimated Probs Leverage for s = 19600: 0.022014339885632082
# Mean Relative Error Estimated Probs L2S for s = 19600: 0.04995175868099126
# Mean Relative Error Estimated Probs Uniform for s = 19600: 0.061057997618737946
# -----------------------------------------------------------------------
# Mean Leverage Misclassification Rate for s = 19600: 0.28406714285714296
# Mean L2S Misclassification Rate for s = 19600: 0.28027500000000005
# Mean Uniform Misclassification Rate for s = 19600: 0.28594214285714287
# -----------------------------------------------------------------------
# Mean Relative Error Leverage Negative Log Likelihood for s = 19600: 0.008042673347743922
# Mean Relative Error L2S Negative Log Likelihood for s = 19600: 0.013511855761772268
# Mean Relative Error Uniform Negative Log Likelihood for s = 19600: 0.7577112845745013
# -----------------------------------------------------------------------
# Mean Relative Error Leverage True Negative Log Likelihood for s = 19600: 0.0005678297328096975
# Mean Relative Error L2S Negative True Log Likelihood for s = 19600: 0.003281533256429124
# Mean Relative Error Uniform True Negative Log Likelihood for s = 19600: 0.005095935468915819
# ============================================================

# %% [markdown]
# # **Plot relative error estimated probabilities for the various sampling**

# %%
# Smooth the curves using a rolling average with window size
window_size =1

smoothed_lev_prob = np.convolve(mean_rel_est_probs_lev_array, np.ones(window_size)/window_size, mode='valid')
smoothed_l2s_prob = np.convolve(mean_rel_est_probs_l2s_array, np.ones(window_size)/window_size, mode='valid')
smoothed_unif_prob = np.convolve(mean_rel_est_probs_unif_array, np.ones(window_size)/window_size, mode='valid')

plt.figure(figsize=(10, 6))

plt.plot(s_values[window_size-1:], smoothed_unif_prob, label="Uniform Sampling", color='b')
plt.plot(s_values[window_size-1:], smoothed_l2s_prob, label="L2S Sampling", color='g')
plt.plot(s_values[window_size-1:], smoothed_lev_prob, label="Leverage Score(this work)", color='r')

plt.xlabel("Sample Size (s)", fontsize=18)
plt.ylabel("Relative error est. probs.",fontsize=18)
plt.legend(fontsize=18)
plt.grid(True, which='both')
plt.yscale('log')  # Set y-axis to log scale
# plt.xscale('log')

plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.savefig('plots\prob_cardio.png', dpi=300)
plt.show()

# %% [markdown]
# # **Plot misclassification rates for the various sampling methods**

# %%
# Smooth the curves using a rolling average with window size
window_size =1

smoothed_lev_mis = np.convolve(mean_lev_misclassification_rate_array, np.ones(window_size)/window_size, mode='valid')
smoothed_l2s_mis = np.convolve(mean_l2s_misclassification_rate_array, np.ones(window_size)/window_size, mode='valid')
smoothed_unif_mis = np.convolve(mean_unif_misclassification_rate_array, np.ones(window_size)/window_size, mode='valid')

plt.figure(figsize=(10, 6))

optimal_misclassification_rate = np.full(len(s_values[window_size-1:]), opt_misclassification_rate)


plt.plot(s_values[window_size-1:], optimal_misclassification_rate, label="Full Data", color='gray', linestyle='-',linewidth=2)
plt.plot(s_values[window_size-1:], smoothed_unif_mis, label="Uniform Sampling", color='b')
plt.plot(s_values[window_size-1:], smoothed_l2s_mis, label="L2S Sampling", color='g')
plt.plot(s_values[window_size-1:], smoothed_lev_mis, label="Leverage Score (this work)", color='r')




plt.xlabel("Sample Size (s)", fontsize=18)
plt.ylabel("Misclassification rate",fontsize=18)
plt.legend(fontsize=18, loc='upper right', bbox_to_anchor=(1, 1))
plt.grid(True, which='both')
plt.yscale('log')  # Set y-axis to log scale
# plt.xscale('log')

plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.savefig('plots\mis_cardio.png', dpi=300)
plt.show()

# %% [markdown]
# # **Plot relative error subsampled NLL for the various sampling methods**

# %%
# Smooth the curves using a rolling average with window size 5
window_size =1

smoothed_lev_NLL = np.convolve(mean_rel_lev_neg_log_likelihood_array, np.ones(window_size)/window_size, mode='valid')
smoothed_l2s_NLL = np.convolve(mean_rel_l2s_neg_log_likelihood_array, np.ones(window_size)/window_size, mode='valid')
smoothed_unif_NLL = np.convolve(mean_rel_unif_neg_log_likelihood_array, np.ones(window_size)/window_size, mode='valid')

# Plot the mean values for misclassification rates with smoothed curves
plt.figure(figsize=(10, 6))


plt.plot(s_values[window_size-1:], smoothed_unif_NLL, label="Uniform Sampling", color='b')
plt.plot(s_values[window_size-1:], smoothed_l2s_NLL, label="L2S Sampling", color='g')
plt.plot(s_values[window_size-1:], smoothed_lev_NLL, label="Leverage Score(this work)", color='r')

plt.xlabel("Sample Size (s)", fontsize=18)
plt.ylabel("Relative error subsampled NLL.",fontsize=18)
plt.legend(fontsize=18)
plt.grid(True, which='both')
plt.legend(fontsize=18, loc='upper right', bbox_to_anchor=(1, 0.8))
plt.yscale('log')  # Set y-axis to log scale
# plt.xscale('log')

plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.savefig('plots\subsampled_NLL_cardio.png', dpi=300)
plt.show()

# %% [markdown]
# # **Plot relative error true NLL for the various sampling methods**

# %%
# Smooth the curves using a rolling average with window size 5
window_size =1

smoothed_lev_true_NLL = np.convolve(mean_rel_lev_true_neg_log_likelihood_array, np.ones(window_size)/window_size, mode='valid')
smoothed_l2s_true_NLL = np.convolve(mean_rel_l2s_true_neg_log_likelihood_array, np.ones(window_size)/window_size, mode='valid')
smoothed_unif_true_NLL = np.convolve(mean_rel_unif_true_neg_log_likelihood_array, np.ones(window_size)/window_size, mode='valid')

# Plot the mean values for misclassification rates with smoothed curves
plt.figure(figsize=(10, 6))


plt.plot(s_values[window_size-1:], smoothed_unif_true_NLL, label="Uniform Sampling", color='b')
plt.plot(s_values[window_size-1:], smoothed_l2s_true_NLL, label="L2S Sampling", color='g')
plt.plot(s_values[window_size-1:], smoothed_lev_true_NLL, label="Leverage Score(this work)", color='r')

plt.xlabel("Sample Size (s)", fontsize=18)
plt.ylabel("Relative error full-data NLL.",fontsize=18)
plt.legend(fontsize=18)
plt.grid(True, which='both')
plt.legend(fontsize=18, loc='upper right', bbox_to_anchor=(1, 1))
plt.yscale('log')  # Set y-axis to log scale
# plt.xscale('log')

plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.savefig('plots\\fulldata_NLL_cardio.png', dpi=300)
plt.show()

# %% [markdown]
# # **Plot the standard deviations**

# %%
# Smooth the curves using a rolling average with window size
window_size =1

smoothed_std_lev_prob = np.convolve(std_rel_est_probs_lev_array, np.ones(window_size)/window_size, mode='valid')
smoothed_std_l2s_prob = np.convolve(std_rel_est_probs_l2s_array, np.ones(window_size)/window_size, mode='valid')
smoothed_std_unif_prob = np.convolve(std_rel_est_probs_unif_array, np.ones(window_size)/window_size, mode='valid')

plt.figure(figsize=(10, 6))

plt.plot(s_values[window_size-1:], smoothed_std_unif_prob, label="Uniform Sampling", color='b')
plt.plot(s_values[window_size-1:], smoothed_std_l2s_prob, label="L2S Sampling", color='g')
plt.plot(s_values[window_size-1:], smoothed_std_lev_prob, label="Leverage Score(this work)", color='r')

plt.xlabel("Sample Size (s)", fontsize=18)
plt.ylabel("Stdev. relative error est. probs.",fontsize=18)
plt.legend(fontsize=18)
plt.grid(True, which='both')
plt.yscale('log')  # Set y-axis to log scale
# plt.xscale('log')

plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.savefig('plots\\stdev_probs_cardio.png', dpi=300)
plt.show()

# %%
# Smooth the curves using a rolling average with window size
window_size =1

smoothed_std_lev_mis = np.convolve(std_lev_misclassification_rate_array, np.ones(window_size)/window_size, mode='valid')
smoothed_std_l2s_mis = np.convolve(std_l2s_misclassification_rate_array, np.ones(window_size)/window_size, mode='valid')
smoothed_std_unif_mis = np.convolve(std_unif_misclassification_rate_array, np.ones(window_size)/window_size, mode='valid')

plt.figure(figsize=(10, 6))



plt.plot(s_values[window_size-1:], smoothed_std_unif_mis, label="Uniform Sampling", color='b')
plt.plot(s_values[window_size-1:], smoothed_std_l2s_mis, label="L2S Sampling", color='g')
plt.plot(s_values[window_size-1:], smoothed_std_lev_mis, label="Leverage Score (this work)", color='r')


plt.xlabel("Sample Size (s)", fontsize=18)
plt.ylabel("Stdev. misclassification rate",fontsize=18)
plt.legend(fontsize=18, loc='upper right', bbox_to_anchor=(1,1))
plt.grid(True, which='both')
plt.yscale('log')  # Set y-axis to log scale
# plt.xscale('log')

plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.savefig('plots\\stdev_mis_cardio.png', dpi=300)
plt.show()

# %%
# Smooth the curves using a rolling average with window size 5
window_size =1

smoothed_std_lev_NLL = np.convolve(std_rel_lev_neg_log_likelihood_array, np.ones(window_size)/window_size, mode='valid')
smoothed_std_l2s_NLL = np.convolve(std_rel_l2s_neg_log_likelihood_array, np.ones(window_size)/window_size, mode='valid')
smoothed_std_unif_NLL = np.convolve(std_rel_unif_neg_log_likelihood_array, np.ones(window_size)/window_size, mode='valid')

# Plot the mean values for misclassification rates with smoothed curves
plt.figure(figsize=(10, 6))


plt.plot(s_values[window_size-1:], smoothed_std_unif_NLL, label="Uniform Sampling", color='b')
plt.plot(s_values[window_size-1:], smoothed_std_l2s_NLL, label="L2S Sampling", color='g')
plt.plot(s_values[window_size-1:], smoothed_std_lev_NLL, label="Leverage Score(this work)", color='r')

plt.xlabel("Sample Size (s)", fontsize=18)
plt.ylabel("Stdev. relative error subsampled NLL",fontsize=18)
plt.legend(fontsize=18)
plt.grid(True, which='both')
plt.legend(fontsize=18, loc='upper right', bbox_to_anchor=(1, 1))
plt.yscale('log')  # Set y-axis to log scale
# plt.xscale('log')

plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.savefig('plots\\stdev_subsampled_NLL_cardio.png', dpi=300)
plt.show()

# %%
# Smooth the curves using a rolling average with window size 5
window_size =1

smoothed_std_lev_true_NLL = np.convolve(std_rel_lev_true_neg_log_likelihood_array, np.ones(window_size)/window_size, mode='valid')
smoothed_std_l2s_true_NLL = np.convolve(std_rel_l2s_true_neg_log_likelihood_array, np.ones(window_size)/window_size, mode='valid')
smoothed_std_unif_true_NLL = np.convolve(std_rel_unif_true_neg_log_likelihood_array, np.ones(window_size)/window_size, mode='valid')

# Plot the mean values for misclassification rates with smoothed curves
plt.figure(figsize=(10, 6))


plt.plot(s_values[window_size-1:], smoothed_std_unif_true_NLL, label="Uniform Sampling", color='b')
plt.plot(s_values[window_size-1:], smoothed_std_l2s_true_NLL, label="L2S Sampling", color='g')
plt.plot(s_values[window_size-1:], smoothed_std_lev_true_NLL, label="Leverage Score(this work)", color='r')

plt.xlabel("Sample Size (s)", fontsize=18)
plt.ylabel("Stdev. relative error full-data NLL",fontsize=18)
plt.legend(fontsize=18)
plt.grid(True, which='both')
plt.legend(fontsize=18, loc='upper right', bbox_to_anchor=(1, 1))
plt.yscale('log')  # Set y-axis to log scale
# plt.xscale('log')

plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.savefig('plots\\stdev_fulldata_NLL_cardio.png', dpi=300)
plt.show()
